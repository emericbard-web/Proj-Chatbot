# %% [markdown]
# # CECCE Chatbot - Phase 5
#
# ## Ask Questions and Inspect Grounding
#
# Dans cette étape, je vais tester les réponses générées par Gemini à partir des documents indexés dans File Search.
#
# Je vais aussi analyser les citations et les sources retournées par le système.
#
# ## Objectifs
#
# - Envoyer des questions à Gemini
# - Tester les réponses
# - Vérifier les citations
# - Vérifier les sources utilisées
# - Tester différents scénarios
