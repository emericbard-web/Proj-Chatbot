# %% [markdown]
# # CECCE Chatbot - Phase 4
#
# ## Upload to Gemini File Search
#
# Dans cette étape, je vais envoyer les fichiers Markdown et PDF dans Gemini File Search afin de créer un corpus de recherche intelligent.
#
# ## Objectifs
#
# - Configurer Gemini API
# - Créer un File Search Store
# - Envoyer les documents
# - Tester l’indexation
# - Vérifier les métadonnées
